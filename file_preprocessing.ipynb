# %%
import os
import random
from PIL import Image

# %%
yourpath = 'C:/Users/rparg/Documents/Data/bacteria_classifier'

# %%
for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        
        print(os.path.join(root, name))
        
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tif":
            if os.path.isfile(os.path.splitext(os.path.join(root, name))[0] + ".jpeg"):
                print ("A jpeg file already exists for %s" % name)
            
            # If a jpeg is *NOT* present, create one from the tiff.
            else:
                outfile = os.path.splitext(os.path.join(root, name))[0] + ".jpeg"
                try:
                    im = Image.open(os.path.join(root, name))
                    print ("Generating jpeg for %s" % name)
                    im.convert(mode="RGB")
                    im.save(outfile)
                except:
                    print('Exception')
                    
# Remove all tif files


for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tif":
            os.remove(os.path.join(root, name))
# Out:
# C:/Users/rparg/Documents/Data/bacteria_classifier\Acinetobacter.baumanii\Acinetobacter.baumanii\Acinetobacter.baumanii_0001.tif
# Generating jpeg for Acinetobacter.baumanii_0001.tif
# C:/Users/rparg/Documents/Data/bacteria_classifier\Acinetobacter.baumanii\Acinetobacter.baumanii\Acinetobacter.baumanii_0002.tif
# Generating jpeg for Acinetobacter.baumanii_0002.tif
# C:/Users/rparg/Documents/Data/bacteria_classifier\Acinetobacter.baumanii\Acinetobacter.baumanii\Acinetobacter.baumanii_0003.tif
# Generating jpeg for Acinetobacter.baumanii_0003.tif
# C:/Users/rparg/Documents/Data/bacteria_classifier\Acinetobacter.baumanii\Acinetobacter.baumanii\Acinetobacter.baumanii_0004.tif
# Generating jpeg for Acinetobacter.baumanii_0004.tif
# C:/Users/rparg/Documents/Data/bacteria_classifier\Acinetobacter.baumanii\Acinetobacter.baumanii\Acinetobacter.baumanii_0005.tif
# Generating jpeg for Acinetobacter.baumanii_0005.tif
# ...

# %%
# Replace '.' with '_' in all file names
for root, dirs, files in os.walk(yourpath, topdown=False):
    for file in files:
        source = str(root).replace('\\','/') + '/' + file
        target = source.replace('.','_',1)
        os.rename(source, target)

# %%
#Split data evenly by label into Train and Test subsets
n = 0.1

for label in os.listdir(yourpath + '/Train'):
    pics = os.listdir(yourpath + '/Train/' +str(label))
    num_pics = len(pics)
    num_test_pics = round(n * num_pics)
    
    test_pics = random.sample(pics, num_test_pics)  # images in each folder

    for p in test_pics:
        file_path = yourpath + '/Train/' +str(label) +'/' + str(p)
        test_path = yourpath + '/Test/' +str(label) + '/'+ str(p)

        os.rename(f'{file_path}', f'{val_path}')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[18], line 14
#      11 file_path = yourpath + '/Train/' +str(label) +'/' + str(p)
#      12 test_path = yourpath + '/Test/' +str(label) + '/'+ str(p)
# ---> 14 os.rename(f'{file_path}', f'{val_path}')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:/Users/rparg/Documents/Data/bacteria_classifier/Train/Acinetobacter_baumanii/Acinetobacter_baumanii_0003.jpeg' -> 'C:/Users/rparg/Documents/Data/bacteria_classifier/Test/Veionella/Veionella_0003_jpeg'
